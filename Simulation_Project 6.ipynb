# %%
# Project for Human Capital Supply and Demand
# Importing libraries
import pandas as pd
import numpy as np

# %%
# reading Excel file
Headcount = pd.read_excel('Demandv1.1.xlsx', 'Headcount',header=0)
Headcount = Headcount[Headcount['Status'] == 'Bench']
Headcount = Headcount.reset_index(drop = True)
Demand_LY = pd.read_excel('Demandv1.1.xlsx', 'Demand Trend Last year',header=0)

# %%
Demand_LY['Month DD Raised'].unique()
# Out:
# array(['May', 'October', 'March', 'June', 'August', 'February', 'January',
#        'December'], dtype=object)

# %%
Supply = Headcount[Headcount['Status'] == 'Bench']

# %%
Supply_Smry = pd.Series(Supply['SkillList'].value_counts())

# %%
Supply_Smry = pd.DataFrame(Supply.pivot_table(index = 'SkillList', columns = 'Status', 
                                                 aggfunc={'Status':np.count_nonzero}))

# %%
#SampleData = pd.merge(Supply_Smry,Demand_Smry, left_index=True, right_index=True)

# %%
#SampleData['Hire'] = SampleData['No. of FTE Request Raised'] - SampleData[SampleData.columns[0]]

# %%
#SampleData[SampleData['Hire'] < 0].sum()

# %%
'''for i in range(SampleData.shape[0]):
    #print(i)
    if SampleData.iloc[i,2] < 0 :
        #print(i)
        SampleData.iloc[i,2] = 0'''
# Out:
# 'for i in range(SampleData.shape[0]):\n    #print(i)\n    if SampleData.iloc[i,2] < 0 :\n        #print(i)\n        SampleData.iloc[i,2] = 0'

# %%
Demand_LY = Demand_LY.sort_values(['Month DD Raised','SkillList','Location'])

# %%
# Sort Demand for Last Year File by Month
rule = {'January':1, 'February':2, 'March':3, 'April':4, 'May':5, 'June':6, 'July':7, 'August':8,
       'September':9, 'October':10, 'November':11, 'December':12}
Demand_LY['Month'] = Demand_LY['Month DD Raised']
Demand_LY['Month'] = Demand_LY['Month'].replace(rule)
Demand_LY = Demand_LY.sort_values(['Month','SkillList','No. of FTE Request Raised','Location'])
Demand_LY = Demand_LY.reset_index(drop = True)

Headcount = Headcount.sort_values(['SkillList','Location'])
Headcount = Headcount.reset_index(drop = True)

# %%
def Generate_Demand(i,Demand_LY) :
    Skill = Demand_LY.ix[i,'SkillList']
    Requirement = Demand_LY.loc[i,'No. of FTE Request Raised']
    Location = Demand_LY.ix[0,'Location']
    Month = Demand_LY.ix[0,'Month DD Raised']

    #print('-----Demand:-----')
    #print('Month:',Month)
    #print('Skill:' ,Skill) 
    #print('Requirement:', Requirement)
    #print('Location:',Location)
    return Skill,Requirement,Location,Month

# %%
def Generate_Supply(Skill,Headcount):
    Supply = Headcount[Headcount['Status'] == 'Bench']
    Bench = Supply[Supply['SkillList'] == Skill]
    #print('-----Bench Available:-----')
    #print('Bench:', Bench.shape[0]), print(pd.DataFrame(Bench['Location']).reset_index(drop = True))
    #print('Hire:',Hire)
    Bench = Check_SubsetSkill_Match(Demand_LY,Headcount,Skill,Supply,Bench)
    Hire = Requirement-Bench.shape[0]
    return Hire,Bench

# %%
rows = []
def Check_SubsetSkill_Match(Demand_LY,Headcount,Skill,Supply,Bench):
    #Supply.reset_index(drop = True)
    #print('----Checking for Subset----',Skill)
    Supply = Supply[Supply['SkillList'] != Skill]
    for i in Supply.index:
        Head_Skill = Supply.loc[i,'SkillList']
        lst1 = list(Head_Skill.split(','))  #list(Supply.loc[i,'SkillList'].split(','))
        lst2 = list(Skill.split(','))
        if (set(lst2).issubset(lst1)) == 1 :
            Bench = Bench.append(Supply.loc[i,])
    return Bench

# %%
Headcount['Relocated City'] = Headcount['Location']
Headcount['Client Date of Joining'] = 'NA'

# %%
def Allocate_Bench(Bench,Location,Month,Headcount):
    # Allocate from Bench
    rows = Bench.index
    Headcount.loc[rows,'Status'] = 'Billable'
    Headcount.loc[rows,'Relocated City'] = Location
    Headcount.loc[rows,'Client Date of Joining'] = Month
    return Headcount

def New_Hire(Month,Skill,Location,Headcount):
    # New Hire Append to Headcount
    new_hire = pd.DataFrame([['Region','Employee Code','Last Name',Month,
                         'Designation','Billable','Market Unit',
                         Skill,Location,Location,Month]], columns = Headcount.columns)
    for j in range(Hire) :
        Headcount = Headcount.append(new_hire, ignore_index=True)
    return Headcount

# %%
import random
def New_Headcount(Headcount):
    Count_of_Attrition = round(.2*(Headcount.shape[0]))
    rows_Bench = list(Headcount[Headcount['Status'] == 'Bench'].index)
    if Count_of_Attrition > len(Headcount[Headcount['Status'] == 'Bench']):
        Count_of_Attrition = len(Headcount[Headcount['Status'] == 'Bench'])
    Attrition = random.sample(rows_Bench, Count_of_Attrition)
    Headcount = Headcount.drop(Attrition)
    return Headcount

# %%
for i in range(Demand_LY.shape[0]):
    Skill,Requirement,Location,Month = Generate_Demand(i,Demand_LY)
    Hire,Bench = Generate_Supply(Skill,Headcount)
    if Bench.shape[0] > 0 :
        Headcount = Allocate_Bench(Bench,Location,Month,Headcount)
    if Hire > 0 :
        Headcount = New_Hire(Month,Skill,Location,Headcount)
    Headcount = New_Headcount(Headcount)
    #input()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
Headcount.shape
# Out:
# (2543, 11)

# %%
Headcount
# Out:
#       Region  Employee Code   Last Name Local Date of Joining  \
# 0         IN          59989      TIWARI   2012-01-22 00:00:00
# 1         UK          39107      TIWARI   2014-08-06 00:00:00
# 2         US          85982    GORIJALA   2010-03-15 00:00:00
# 3         US          36375   KHARBANDA   2012-07-30 00:00:00
# 4         UK          33948      SHARMA   2015-08-05 00:00:00
# 5         IN          91011     SAKHARE   2017-09-01 00:00:00
# 6         SG          27223      RASIDI   2000-08-07 00:00:00
# 7         IN          24313      PILLAI   2002-10-15 00:00:00
# 8         US          75827       JOHRI   2006-08-28 00:00:00
# 9     Region  Employee Code   Last Name               January
# 10    Region  Employee Code   Last Name               January
# 11    Region  Employee Code   Last Name               January
# 12    Region  Employee Code   Last Name               January
# 13    Region  Employee Code   Last Name               January
# 14    Region  Employee Code   Last Name               January
# 15    Region  Employee Code   Last Name               January
# 16    Region  Employee Code   Last Name               January
# 17    Region  Employee Code   Last Name               January
# 18    Region  Employee Code   Last Name               January
# 19    Region  Employee Code   Last Name               January
# 20    Region  Employee Code   Last Name               January
# 21    Region  Employee Code   Last Name               January
# 22    Region  Employee Code   Last Name               January
# 23    Region  Employee Code   Last Name               January
# 24    Region  Employee Code   Last Name               January
# 25    Region  Employee Code   Last Name               January
# 26    Region  Employee Code   Last Name               January
# 27    Region  Employee Code   Last Name               January
# 28    Region  Employee Code   Last Name               January
# 29    Region  Employee Code   Last Name               January
# ...      ...            ...         ...                   ...
# 2513  Region  Employee Code   Last Name               January
# 2514  Region  Employee Code   Last Name               January
# 2515  Region  Employee Code   Last Name               January
# 2516  Region  Employee Code   Last Name               January
# 2517  Region  Employee Code   Last Name               January
# 2518  Region  Employee Code   Last Name               January
# 2519  Region  Employee Code   Last Name               January
# 2520  Region  Employee Code   Last Name               January
# 2521  Region  Employee Code   Last Name               January
# 2522  Region  Employee Code   Last Name               January
# 2523  Region  Employee Code   Last Name               January
# 2524  Region  Employee Code   Last Name               January
# 2525  Region  Employee Code   Last Name               January
# 2526  Region  Employee Code   Last Name               January
# 2527  Region  Employee Code   Last Name               January
# 2528  Region  Employee Code   Last Name               January
# 2529  Region  Employee Code   Last Name               January
# 2530  Region  Employee Code   Last Name               January
# 2531  Region  Employee Code   Last Name               January
# 2532  Region  Employee Code   Last Name               January
# 2533  Region  Employee Code   Last Name               January
# 2534  Region  Employee Code   Last Name               January
# 2535  Region  Employee Code   Last Name               January
# 2536  Region  Employee Code   Last Name               January
# 2537  Region  Employee Code   Last Name               January
# 2538  Region  Employee Code   Last Name               January
# 2539  Region  Employee Code   Last Name               January
# 2540  Region  Employee Code   Last Name               January
# 2541  Region  Employee Code   Last Name               January
# 2542  Region  Employee Code   Last Name               January
#
#             Designation    Status  Market Unit  \
# 0     PORTFOLIO MANAGER  Billable          NaN
# 1               MANAGER  Billable          NaN
# 2     PORTFOLIO MANAGER  Billable         BANK
# 3               MANAGER  Billable          INS
# 4               MANAGER  Billable          INS
# 5               MANAGER  Billable          INS
# 6     SENIOR CONSULTANT  Billable          INS
# 7        SENIOR MANAGER  Billable         BANK
# 8     PORTFOLIO MANAGER  Billable           GP
# 9           Designation  Billable  Market Unit
# 10          Designation  Billable  Market Unit
# 11          Designation  Billable  Market Unit
# 12          Designation  Billable  Market Unit
# 13          Designation  Billable  Market Unit
# 14          Designation  Billable  Market Unit
# 15          Designation  Billable  Market Unit
# 16          Designation  Billable  Market Unit
# 17          Designation  Billable  Market Unit
# 18          Designation  Billable  Market Unit
# 19          Designation  Billable  Market Unit
# 20          Designation  Billable  Market Unit
# 21          Designation  Billable  Market Unit
# 22          Designation  Billable  Market Unit
# 23          Designation  Billable  Market Unit
# 24          Designation  Billable  Market Unit
# 25          Designation  Billable  Market Unit
# 26          Designation  Billable  Market Unit
# 27          Designation  Billable  Market Unit
# 28          Designation  Billable  Market Unit
# 29          Designation  Billable  Market Unit
# ...                 ...       ...          ...
# 2513        Designation  Billable  Market Unit
# 2514        Designation  Billable  Market Unit
# 2515        Designation  Billable  Market Unit
# 2516        Designation  Billable  Market Unit
# 2517        Designation  Billable  Market Unit
# 2518        Designation  Billable  Market Unit
# 2519        Designation  Billable  Market Unit
# 2520        Designation  Billable  Market Unit
# 2521        Designation  Billable  Market Unit
# 2522        Designation  Billable  Market Unit
# 2523        Designation  Billable  Market Unit
# 2524        Designation  Billable  Market Unit
# 2525        Designation  Billable  Market Unit
# 2526        Designation  Billable  Market Unit
# 2527        Designation  Billable  Market Unit
# 2528        Designation  Billable  Market Unit
# 2529        Designation  Billable  Market Unit
# 2530        Designation  Billable  Market Unit
# 2531        Designation  Billable  Market Unit
# 2532        Designation  Billable  Market Unit
# 2533        Designation  Billable  Market Unit
# 2534        Designation  Billable  Market Unit
# 2535        Designation  Billable  Market Unit
# 2536        Designation  Billable  Market Unit
# 2537        Designation  Billable  Market Unit
# 2538        Designation  Billable  Market Unit
# 2539        Designation  Billable  Market Unit
# 2540        Designation  Billable  Market Unit
# 2541        Designation  Billable  Market Unit
# 2542        Designation  Billable  Market Unit
#
#                                               SkillList     Location  \
# 0         (D) Capital Markets Sector,Financial Services  Bhubaneswar
# 1         (D) Capital Markets Sector,Financial Services    Hyderabad
# 2                                         .Net with MVC        Noida
# 3                         .Net with MVC,SQL Server 2012         Pune
# 4                                             Ab Initio    Bangalore
# 5                                             Ab Initio    Hyderabad
# 6                                             Ab Initio         Pune
# 7        Java,API Integrations- REST, SOAP , Powershell      Gurgaon
# 8     Spring Batch,API Integrations- REST, SOAP , Po...     Hartford
# 9         (D) Capital Markets Sector,Financial Services      Chennai
# 10        (D) Capital Markets Sector,Financial Services      Chennai
# 11                      (T) Data and Semantic Modelling      Chennai
# 12                                            .Net (WF)      Chennai
# 13            API Integrations- REST, SOAP , Powershell      Chennai
# 14            API Integrations- REST, SOAP , Powershell      Chennai
# 15            API Integrations- REST, SOAP , Powershell      Chennai
# 16            API Integrations- REST, SOAP , Powershell      Chennai
# 17                                            Ab Initio      Chennai
# 18                                            Ab Initio      Chennai
# 19                                            Ab Initio      Chennai
# 20                                            Ab Initio      Chennai
# 21                                            Ab Initio      Chennai
# 22                                            Ab Initio      Chennai
# 23                                            Ab Initio      Chennai
# 24                                            Ab Initio      Chennai
# 25                                            Ab Initio      Chennai
# 26                                            Ab Initio      Chennai
# 27                                            Ab Initio      Chennai
# 28                                            Ab Initio      Chennai
# 29                                            Ab Initio      Chennai
# ...                                                 ...          ...
# 2513                                                SQL      Chennai
# 2514                                                SQL      Chennai
# 2515                                                SQL      Chennai
# 2516                                            SQL,ETL      Chennai
# 2517                                            SQL,ETL      Chennai
# 2518                                            SQL,ETL      Chennai
# 2519                                            SQL,ETL      Chennai
# 2520                                           Selenium      Chennai
# 2521                                           Selenium      Chennai
# 2522                                           Selenium      Chennai
# 2523                                           Selenium      Chennai
# 2524                                           Selenium      Chennai
# 2525                                           Selenium      Chennai
# 2526                            Selenium,Quick Test Pro      Chennai
# 2527                                     Selenium,TOSCA      Chennai
# 2528                                           Teradata      Chennai
# 2529                                           Teradata      Chennai
# 2530                                           Teradata      Chennai
# 2531                                           Teradata      Chennai
# 2532                                           Teradata      Chennai
# 2533                                           Teradata      Chennai
# 2534                                    Test Automation      Chennai
# 2535                                    Test Automation      Chennai
# 2536  Test Reporting,Informatica BI,Test Case Execut...      Chennai
# 2537  Test Reporting,Informatica BI,Test Case Execut...      Chennai
# 2538                                        Thunderhead      Chennai
# 2539                                                 UI      Chennai
# 2540                      VisionPlus CMS,VisionPlus FAS      Chennai
# 2541                      VisionPlus CMS,VisionPlus FAS      Chennai
# 2542                      VisionPlus CMS,VisionPlus FAS      Chennai
#
#      Relocated City Client Date of Joining
# 0           Chennai                January
# 1           Chennai                January
# 2           Chennai                January
# 3           Chennai                January
# 4           Chennai                January
# 5           Chennai                January
# 6           Chennai                January
# 7           Chennai                January
# 8           Chennai                January
# 9           Chennai                January
# 10          Chennai                January
# 11          Chennai                January
# 12          Chennai                January
# 13          Chennai                January
# 14          Chennai                January
# 15          Chennai                January
# 16          Chennai                January
# 17          Chennai                January
# 18          Chennai                January
# 19          Chennai                January
# 20          Chennai                January
# 21          Chennai                January
# 22          Chennai                January
# 23          Chennai                January
# 24          Chennai                January
# 25          Chennai                January
# 26          Chennai                January
# 27          Chennai                January
# 28          Chennai                January
# 29          Chennai                January
# ...             ...                    ...
# 2513        Chennai                January
# 2514        Chennai                January
# 2515        Chennai                January
# 2516        Chennai                January
# 2517        Chennai                January
# 2518        Chennai                January
# 2519        Chennai                January
# 2520        Chennai                January
# 2521        Chennai                January
# 2522        Chennai                January
# 2523        Chennai                January
# 2524        Chennai                January
# 2525        Chennai                January
# 2526        Chennai                January
# 2527        Chennai                January
# 2528        Chennai                January
# 2529        Chennai                January
# 2530        Chennai                January
# 2531        Chennai                January
# 2532        Chennai                January
# 2533        Chennai                January
# 2534        Chennai                January
# 2535        Chennai                January
# 2536        Chennai                January
# 2537        Chennai                January
# 2538        Chennai                January
# 2539        Chennai                January
# 2540        Chennai                January
# 2541        Chennai                January
# 2542        Chennai                January
#
# [2543 rows x 11 columns]
